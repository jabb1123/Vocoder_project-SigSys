# %%
from __future__ import print_function, division

import thinkdsp
import thinkplot

# %matplotlib inline

cos_sig = thinkdsp.CosSignal(freq = 440, amp =1.0, offset = 0)
wave = cos_sig.make_wave(duration = 2, start = 0, framerate = 11025)

# %%
spectrum = wave.make_spectrum()
spectrum.plot()

# %%
signal = thinkdsp.UncorrelatedGaussianNoise()
wave = signal.make_wave(duration=0.49, framerate=11025)
wave.plot(linewidth=1)

# %%
wave = signal.make_wave()
spec = wave.make_spectrum()
spec.plot()

# %%
spec2 = spec
spec = spec.pink_filter()
spec = spec.pink_filter()
spec2 = spec2.pink_filter(2)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-22-b152aa53554a> in <module>()
#       1 spec2 = spec
# ----> 2 spec = spec.pink_filter()
#       3 spec = spec.pink_filter()
#       4 spec2 = spec2.pink_filter(2)
#
# AttributeError: 'NoneType' object has no attribute 'pink_filter'
