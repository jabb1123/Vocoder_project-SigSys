# %%
from __future__ import print_function, division

import thinkdsp
import thinkplot

# %%
filename = '28917__junggle__btn107.wav'
wave = thinkdsp.read_wave('28917__junggle__btn107.wav')
wave.plot()
wave.make_audio()
start = 0.4
duration = 0.2
segment = wave.segment(start, duration)
segment.plot()
