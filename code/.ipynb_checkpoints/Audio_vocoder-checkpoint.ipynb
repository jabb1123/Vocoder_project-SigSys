# %%
import numpy as np
import thinkdsp
import thinkplot
import matplotlib.pyplot as plt


# %matplotlib inline

# %%
sample = 1.0/200 #samples per second to test against
pitch = 220
sig_type = 'sin'
filename =  'flesh_wound.wav'

# %%
v_wave = thinkdsp.read_wave(filename)
print(v_wave.duration)
print(v_wave.framerate)
#wave.normalize()
wave.apodize()
v_wave.make_audio()
# Out:
# 6.15328798186
# 11025
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-3f735d910f01> in <module>()
#       3 print(v_wave.framerate)
#       4 #wave.normalize()
# ----> 5 wave.apodize()
#       6 v_wave.make_audio()
#       7
#
# NameError: name 'wave' is not defined

# %%
v_wave.plot()

# %%
vSeg = []
for s in np.arange(0,v_wave.duration,sample):
    vSeg.append(v_wave.segment(s,sample))

# %%
v_spectrum = v_wave.make_spectrum()
print(v_spectrum.framerate)
v_spectrum.plot()
# Out:
# 11025

# %%
if sig_type == 'saw':
    sig = thinkdsp.SawtoothSignal(freq=pitch, amp=0.5, offset=0)
elif sig_type == 'sin':
    sig = thinkdsp.SinSignal(freq=pitch, amp=1, offset=0)
elif sig_type == 'cos':
    sig = thinkdsp.CosSignal(freq=pitch, amp=1, offset=0)
elif sig_type == 'tri':
    sig = thinkdsp.TriangleSignal(freq=pitch, amp=0.5, offset=0)
elif sig_type == 'sqr':
    sig = thinkdsp.SquareSignal(freq=pitch, amp=0.5, offset=0)
elif sig_type == 'par':
    sig = thinkdsp.ParabolicSignal(freq=pitch, amp=0.5, offset=0)
sig = thinkdsp.SawtoothSignal(freq=pitch, amp=0.5, offset=0)
wave=sig.make_wave(framerate = v_wave.framerate, duration = v_wave.duration)
#wave.normalize()
wave.apodize()
wave.plot()
wave.make_audio()
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
Seg = []
for s in np.arange(0,wave.duration,sample):
    Seg.append(wave.segment(s,sample))

# %%
spec = wave.make_spectrum()
print(spec.framerate)
spec.plot()
# Out:
# 11025

# %%
print(vSeg[0].make_spectrum().hs)
print(Seg[0].make_spectrum().hs)
x = vSeg[0].make_spectrum()
y = Seg[0].make_spectrum()
print()
(x.amps*y.amps)*(np.cos(y.angles())+(np.sin(y.angles())*1j))
# Out:
# [-12287.00000000   +0.j           1404.91804770+8612.12189979j
#    -893.80003697+1338.50529331j   3922.73899105+2090.31612113j
#    2062.65019053+5802.17365259j  -2197.35781373-1306.91919206j
#    -500.89085066+5183.91155798j  -6228.22802749-3626.6785318j
#    4443.95756184+4057.14754902j   5770.86558878+3294.0597071j
#   -4354.36585036-4806.20645742j  -4798.72392553-2441.6169265j
#    9886.03335468 +136.11241288j  -7245.95407003-1536.42171948j
#   -4910.94350169-5823.34201217j   -203.25157930+1225.66316282j
#    -273.12092684-3648.5944066j    2605.61880549-2632.48889268j
#   -2934.48428367-1619.34278207j   2645.32257645+2482.06299491j
#     648.63739192 +525.65545073j   3420.03027446+3107.6956982j
#      64.72392553+2897.93879925j   1839.96131486 +194.12184374j
#   -1736.57067305+2449.67259614j  -1874.16214854-2761.47897375j
#   -1091.13190855-2018.50598j      -368.97242687-1964.98418994j]
# [ 0.11319128+0.j         -0.04368313+0.20838346j -0.13243715+0.03121511j
#  -0.11487640-0.0465336j  -0.07625394-0.0866686j  -0.03286475-0.10124281j
#   0.00666429-0.09621307j  0.03660442-0.07727594j  0.05377289-0.05065169j
#   0.05758456-0.02260235j  0.04984830+0.00139581j  0.03420648+0.0174316j
#   0.01529386+0.02366534j -0.00222703+0.02044489j -0.01456810+0.01001224j
#  -0.01948503-0.00412993j -0.01659401-0.01805351j -0.00729048-0.02826711j
#   0.00569361-0.03242989j  0.01898543-0.02977843j  0.02936293-0.02119135j
#   0.03447133-0.00889458j  0.03331460+0.00411504j  0.02642419+0.01479265j
#   0.01567933+0.02075225j  0.00382824+0.02080273j -0.00617608+0.01519838j
#  -0.01187399+0.00555365j]
# ()
# array([-12287.00000000 +1.50472352e-12j,   1404.91804770 +8.61212190e+03j,
#          -893.80003697 +1.33850529e+03j,   3922.73899105 +2.09031612e+03j,
#          2062.65019053 +5.80217365e+03j,  -2197.35781373 -1.30691919e+03j,
#          -500.89085066 +5.18391156e+03j,  -6228.22802749 -3.62667853e+03j,
#          4443.95756184 +4.05714755e+03j,   5770.86558878 +3.29405971e+03j,
#         -4354.36585036 -4.80620646e+03j,  -4798.72392553 -2.44161693e+03j,
#          9886.03335468 +1.36112413e+02j,  -7245.95407003 -1.53642172e+03j,
#         -4910.94350169 -5.82334201e+03j,   -203.25157930 +1.22566316e+03j,
#          -273.12092684 -3.64859441e+03j,   2605.61880549 -2.63248889e+03j,
#         -2934.48428367 -1.61934278e+03j,   2645.32257645 +2.48206299e+03j,
#           648.63739192 +5.25655451e+02j,   3420.03027446 +3.10769570e+03j,
#            64.72392553 +2.89793880e+03j,   1839.96131486 +1.94121844e+02j,
#         -1736.57067305 +2.44967260e+03j,  -1874.16214854 -2.76147897e+03j,
#         -1091.13190855 -2.01850598e+03j,   -368.97242687 -1.96498419e+03j])

# %%
frames= v_wave.framerate
for i in range(len(vSeg)):
    Voc_Spec=thinkdsp.Spectrum(hs = vSeg[i].make_spectrum().amps*Seg[i].make_spectrum().amps,framerate = frames)
    if i == 0:
        voc_s = Voc_Spec.make_wave()
    else:
         voc_s |= Voc_Spec.make_wave()
voc_s.plot()

# %%
voc_s.make_spectrum().plot()

# %%
voc_s.normalize()
voc_s.make_audio()

# %%
test = wave+v_wave
test.plot()

# %%
test.make_audio()
